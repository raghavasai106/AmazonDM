# %% [markdown]
# # Amazon Dataset Analysis and visualization by Group 4

# %%
import pandas as pd
import random
import numpy as np
import re

# %%
import pandas as pd
import os
os.chdir("/Users/raghavasaikowlasker/PycharmProjects/AmazonDM")
print("Current Working Directory " , os.getcwd())
df = pd.read_csv("/Users/raghavasaikowlasker/PycharmProjects/AmazonDM/Amazon_Dataset.csv")
# Displays top 5 rows
df.head(5)
# Displays whole table
df
# Out:
# Current Working Directory  /Users/raghavasaikowlasker/PycharmProjects/AmazonDM
#                                uniq_id   manufacturer   price  \
# 0     eac7efa5dbd3d667f26eb3d3ab504464         Hornby    3.42
# 1     348f344247b0c1a935b1223072ef9d8a            ccf    9.99
# 2     e33a9adeed5f36840ccc227db4682a36         Hornby   32.19
# 3     87bbb472ef9d90dcef140a551665c929         Hornby   69.93
# 4     03a35de3f7af9814978e6de645cb8ffa         Hornby  119.50
# ...                                ...            ...     ...
# 3368  5962c0a2623129d656aac1ee19239dcb         Marvel   11.95
# 3369  0c99ecefabf3ec25d4fae53d0646fb3b    Thundercats   11.44
# 3370  57c638712b4ecb8dac1ec3004039f1f1  Power Rangers    9.75
# 3371  44d6967f083825a5de36ad4865a65bcd         Mattel   22.95
# 3372  94d18e86e504bee1e392df7e5738b18a         Bandai   21.20
#
#       number_of_reviews product_name_new              category  \
# 0                    15  Hornby 2014 Cat              Hobbies
# ...

# %%
import plotly.graph_objects as go
import pandas as pd
e = pd.read_csv("Amazon_Dataset.csv")
df=pd.DataFrame(e)

fig = go.Figure([go.Histogram(x=df['category'], y=df['manufacturer'].unique())])
fig.update_layout(title_text="Number of manufacturers for each category  ")
fig.update_xaxes(title_text="Category")
fig.update_yaxes(title_text="Number of manufacturer")
fig.show()
# Out:
# <div>                            <div id="da288c16-2323-43d3-97d1-2455bcecd6d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da288c16-2323-43d3-97d1-2455bcecd6d3")) {                    Plotly.newPlot(                        "da288c16-2323-43d3-97d1-2455bcecd6d3",                        [{"x":["Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies "
# ...

# %%
import plotly.express as px
import pandas as pd
import plotly.graph_objects as go

e = pd.read_csv ('/Users/raghavasaikowlasker/PycharmProjects/AmazonDM/Amazon_Dataset.csv')
df=pd.DataFrame(e)
filter_reviews = df[df['number_of_reviews'] > 300]
fig = px.pie(filter_reviews, values='number_of_reviews', names='manufacturer',title='Total Reviews for Each Manufacturer',color_discrete_sequence=px.colors.sequential.RdBu
             , hover_data=['category'], labels={'reviews':'number_of_reviews'})
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <div>                            <div id="ca0afb43-5b73-4899-bd94-51cbd8e1e82f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca0afb43-5b73-4899-bd94-51cbd8e1e82f")) {                    Plotly.newPlot(                        "ca0afb43-5b73-4899-bd94-51cbd8e1e82f",                        [{"customdata":[["Games "],["Arts & Crafts "],["Storage, Cleaning & Ring Sizers "],["Arts & Crafts "],["Arts & Crafts "],["Fancy Dress "],["Fancy Dress "],["Puppets & Puppet Theatres "],["Puppets & Puppet Theatres "],["Games "],["Characters & Brands "],["Sports Toys & Outdoor "],["Puppets & Puppet Theatres "],["Pretend Play "],["Characters & Brands "],["Figures & Playsets "],["Games "],["Games "],["Characters & Brands "]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"ho
# ...

# %%
import pandas as pd

df = pd.read_csv("Amazon_Dataset.csv")


# Displays top 5 rows
df.head(5)

print('Number of Unique elements in column manufacturers and category')
uniqueValue = (df['manufacturer'].nunique(),df['category'].nunique(),df['product_name_new'].nunique(),df['subcategory'].nunique())
print(uniqueValue)
unum = (df.manufacturer.unique(),df.category.unique())
print('Unique elements in column manufacturers and category')
unum
# Out:
# Number of Unique elements in column manufacturers and category
# (1141, 32, 2699, 125)
# Unique elements in column manufacturers and category
# (array(['Hornby', 'ccf', 'Gaugemaster', ..., 'SMART SHOPPING', 'Abystyle',
#         'Square-Enix'], dtype=object),
#  array(['Hobbies ', 'Characters & Brands ', 'Bags ', 'Games ',
#         'Arts & Crafts ', 'Figures & Playsets ', 'Home Accessories ',
#         'Die-Cast & Toy Vehicles ', 'Storage, Cleaning & Ring Sizers ',
#         'Bedding & Linens ', 'Sports Toys & Outdoor ', 'Camping & Hiking ',
#         'Pretend Play ', 'Fancy Dress ', 'Women ', 'Electronic Toys ',
#         'Baby & Toddler Toys ', 'Party Supplies ', 'Dolls & Accessories ',
#         'Educational Toys ', 'Sweets, Chocolate & Gum ',
#         'Musical Toy Instruments ', 'Men ', 'Cooking & Dining ',
#         'Medication & Remedies ', 'Puppets & Puppet Theatres ',
#         'Indoor Lighting ', 'Jigsaws & Puzzles ', 'Office Supplies ',
# ...

# %% [markdown]
# # 32 categories having 125 subcategories with over 1141 manufacturers selling over 2669 products.

# %%
import plotly.graph_objects as go
import pandas as pd
import plotly.express as px
e = pd.read_csv("Amazon_Dataset.csv")
df=pd.DataFrame(e)
fig = px.histogram(df, y= df['Rating'], x="category", color_discrete_sequence=['indianred'])
fig.update_layout(title_text="Highest gross Ratings for Each Category")
fig.update_xaxes(title_text="Category")
fig.update_yaxes(title_text="Total Ratings")
fig.show()
# Out:
# <div>                            <div id="7f5d26bf-5101-45ed-aae7-b7bd91ba364d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f5d26bf-5101-45ed-aae7-b7bd91ba364d")) {                    Plotly.newPlot(                        "7f5d26bf-5101-45ed-aae7-b7bd91ba364d",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"category=%{x}<br>sum of Rating=%{y}<extra></extra>","legendgroup":"","marker":{"color":"indianred","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Hobbies ","Ho
# ...

# %%
import plotly.graph_objects as go
import pandas as pd
import plotly.express as px
e = pd.read_csv("Amazon_Dataset.csv")
df=pd.DataFrame(e)

fig = px.pie(df, values='Rating', names='subcategory',title='Gross Ratings for each SubCategory'
             , hover_data=['category'], labels={'reviews':'number_of_reviews'})
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <div>                            <div id="37d6c870-28f6-4345-88f7-ce34e6a05c85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37d6c870-28f6-4345-88f7-ce34e6a05c85")) {                    Plotly.newPlot(                        "37d6c870-28f6-4345-88f7-ce34e6a05c85",                        [{"customdata":[["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies "],["Hobbies 
# ...

# %%
import plotly.express as px
import math
import dash
e = pd.read_csv("Amazon_Dataset.csv")
df=pd.DataFrame(e)
fig = px.treemap(df, path=['category','subcategory'], values='price',
                  color='price', title = 'Average Pricing with respect Category/Subcategory')
fig.show()
